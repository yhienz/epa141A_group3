# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import ema_workbench
import seaborn as sns
from ema_workbench import load_results

experiments, outcomes = load_results('W24_Open_Exploration_5t_10_3_PD6.tar.gz')

experiments
# Out:
#     A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                        36  215.681867      10.0   0.211862   38.310347
# 1                        93   82.313012       1.0   0.524293  177.096100
# 2                        26  268.376640       1.0   0.671486  310.281314
# 3                        69  150.752937       1.5   0.139880  239.092283
# 4                         8  306.116391       1.5   0.711591   65.579101
# 5                        64  328.571421      10.0   0.835408  215.505186
# 6                        49  173.610302       1.0   0.477524  318.432285
# 7                       126  237.136733       1.5   0.089698  272.247631
# 8                       110  108.436632       1.0   0.380222  144.154817
# 9                        91   61.201801      10.0   0.972461  104.012462
# 10                       36  215.681867      10.0   0.211862   38.310347
# 11                       93   82.313012       1.0   0.524293  177.096100
# ...
