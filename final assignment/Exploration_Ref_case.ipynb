# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import ema_workbench
import seaborn as sns
from ema_workbench import load_results

experiments, outcomes = load_results('Week23_reference_case_2000_6.tar.gz')
df_exp = pd.DataFrame.from_dict(experiments)
df_out = pd.DataFrame.from_dict(outcomes)

# %%
df_exp
# Out:
#        A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                          114  328.682725       1.5   0.713485  139.532438
# 1                           18  271.151740      10.0   0.041304   43.558330
# 2                           90  197.650243       1.0   0.740644   62.931004
# 3                           95  267.976883       1.0   0.783014   66.409068
# 4                           23   44.151139       1.5   0.419052   55.031186
# ...                        ...         ...       ...        ...         ...
# 11995                       32  109.898647      10.0   0.220167  138.864127
# 11996                      103  265.025510       1.5   0.443085   49.628131
# 11997                       34  108.275372       1.0   0.593292  346.476214
# 11998                       73  281.357288       1.5   0.907884  175.526513
# 11999                      128  166.768248       1.0   0.492701   80.190843
#
#       A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0           1.0   0.515097  228.360825      10.0   0.865021  ...
# 1          10.0   0.133565  202.056870       1.0   0.096704  ...
# 2           1.0   0.054134  109.606651       1.0   0.293149  ...
# 3          10.0   0.472811  230.959702       1.0   0.818138  ...
# 4           1.0   0.080026  233.709638       1.5   0.976588  ...
# ...         ...        ...         ...       ...        ...  ...
# 11995       1.0   0.539569  169.620790       1.5   0.436351  ...
# 11996       1.0   0.562165   84.138305       1.5   0.799322  ...
# 11997       1.5   0.217539  163.567916       1.5   0.965051  ...
# 11998       1.0   0.825676  335.324553       1.5   0.084136  ...
# 11999       1.0   0.490096  133.256108       1.0   0.709647  ...
#
#        A.3_DikeIncrease 2 A.4_DikeIncrease 0  A.4_DikeIncrease 1  \
# 0                       0                  1                   0
# 1                       0                  1                   0
# 2                       0                  1                   0
# 3                       0                  1                   0
# 4                       0                  1                   0
# ...                   ...                ...                 ...
# 11995                   0                  0                   0
# 11996                   0                  0                   0
# 11997                   0                  0                   0
# 11998                   0                  0                   0
# 11999                   0                  0                   0
#
#        A.4_DikeIncrease 2 A.5_DikeIncrease 0  A.5_DikeIncrease 1  \
# 0                       0                  1                   0
# 1                       0                  1                   0
# 2                       0                  1                   0
# 3                       0                  1                   0
# 4                       0                  1                   0
# ...                   ...                ...                 ...
# 11995                   0                  0                   0
# 11996                   0                  0                   0
# 11997                   0                  0                   0
# 11998                   0                  0                   0
# 11999                   0                  0                   0
#
#       A.5_DikeIncrease 2 scenario policy     model
# 0                      0     2000      0  dikesnet
# 1                      0     2001      0  dikesnet
# 2                      0     2002      0  dikesnet
# 3                      0     2003      0  dikesnet
# 4                      0     2004      0  dikesnet
# ...                  ...      ...    ...       ...
# 11995                  0     3995      5  dikesnet
# 11996                  0     3996      5  dikesnet
# 11997                  0     3997      5  dikesnet
# 11998                  0     3998      5  dikesnet
# 11999                  0     3999      5  dikesnet
#
# [12000 rows x 53 columns]

# %%
df_tot = pd.concat([df_exp, df_out], axis=1)
df_tot_p0= df_tot[df_tot['policy']==0]
df_tot_p1= df_tot[df_tot['policy']==1]
df_tot_p2= df_tot[df_tot['policy']==2]
df_tot_p3= df_tot[df_tot['policy']==3]
df_tot_p4= df_tot[df_tot['policy']==4]
df_tot_p5= df_tot[df_tot['policy']==5]

df_tot_p0
# Out:
#       A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                         114  328.682725       1.5   0.713485  139.532438
# 1                          18  271.151740      10.0   0.041304   43.558330
# 2                          90  197.650243       1.0   0.740644   62.931004
# 3                          95  267.976883       1.0   0.783014   66.409068
# 4                          23   44.151139       1.5   0.419052   55.031186
# ...                       ...         ...       ...        ...         ...
# 1995                       32  109.898647      10.0   0.220167  138.864127
# 1996                      103  265.025510       1.5   0.443085   49.628131
# 1997                       34  108.275372       1.0   0.593292  346.476214
# 1998                       73  281.357288       1.5   0.907884  175.526513
# 1999                      128  166.768248       1.0   0.492701   80.190843
#
#      A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0          1.0   0.515097  228.360825      10.0   0.865021  ...
# 1         10.0   0.133565  202.056870       1.0   0.096704  ...
# 2          1.0   0.054134  109.606651       1.0   0.293149  ...
# 3         10.0   0.472811  230.959702       1.0   0.818138  ...
# 4          1.0   0.080026  233.709638       1.5   0.976588  ...
# ...        ...        ...         ...       ...        ...  ...
# 1995       1.0   0.539569  169.620790       1.5   0.436351  ...
# 1996       1.0   0.562165   84.138305       1.5   0.799322  ...
# 1997       1.5   0.217539  163.567916       1.5   0.965051  ...
# 1998       1.0   0.825676  335.324553       1.5   0.084136  ...
# 1999       1.0   0.490096  133.256108       1.0   0.709647  ...
#
#       A.5_DikeIncrease 1 A.5_DikeIncrease 2  scenario  policy     model  \
# 0                      0                  0      2000       0  dikesnet
# 1                      0                  0      2001       0  dikesnet
# 2                      0                  0      2002       0  dikesnet
# 3                      0                  0      2003       0  dikesnet
# 4                      0                  0      2004       0  dikesnet
# ...                  ...                ...       ...     ...       ...
# 1995                   0                  0      3995       0  dikesnet
# 1996                   0                  0      3996       0  dikesnet
# 1997                   0                  0      3997       0  dikesnet
# 1998                   0                  0      3998       0  dikesnet
# 1999                   0                  0      3999       0  dikesnet
#
#       Expected Annual Damage A4 Expected Annual Damage A5  \
# 0                  0.000000e+00              1.055849e+09
# 1                  0.000000e+00              0.000000e+00
# 2                  5.148609e+06              0.000000e+00
# 3                  0.000000e+00              0.000000e+00
# 4                  1.713662e+07              0.000000e+00
# ...                         ...                       ...
# 1995               8.589139e+07              0.000000e+00
# 1996               2.971145e+06              0.000000e+00
# 1997               0.000000e+00              0.000000e+00
# 1998               0.000000e+00              0.000000e+00
# 1999               1.556982e+06              8.151346e+07
#
#      Expected Number of Deaths in A4 Expected Number of Deaths in A5  \
# 0                           0.000000                        1.061388
# 1                           0.000000                        0.000000
# 2                           0.002026                        0.000000
# 3                           0.000000                        0.000000
# 4                           0.007911                        0.000000
# ...                              ...                             ...
# 1995                        0.031714                        0.000000
# 1996                        0.002001                        0.000000
# 1997                        0.000000                        0.000000
# 1998                        0.000000                        0.000000
# 1999                        0.000703                        0.065222
#
#        Total Costs
# 0     1.196643e+09
# 1     2.470161e+09
# 2     1.306670e+09
# 3     1.793552e+08
# 4     1.088269e+09
# ...            ...
# 1995  4.743243e+08
# 1996  1.329333e+08
# 1997  5.097466e+08
# 1998  2.118404e+09
# 1999  2.605459e+08
#
# [2000 rows x 58 columns]

# %%
df_tot_p0_costs = df_tot_p0[['Total Costs']]
df_tot_p0_deathsA5 = df_tot_p0[['Expected Number of Deaths in A5']]
df_tot_p0_deathsA4 = df_tot_p0[['Expected Number of Deaths in A4']]
df_tot_p0_damageA5 = df_tot_p0[['Expected Annual Damage A5']]
df_tot_p0_damageA4 = df_tot_p0[['Expected Annual Damage A4']]
fig, axs = plt.subplots(1, 5, figsize=(12, 6))

# Boxplot for df_out_deaths in A5
df_tot_p0_deathsA5.boxplot(ax=axs[0])
axs[0].set_title('Total Deaths in A5')
axs[0].set_ylabel('Number of Deaths')

# Boxplot for df_out_deaths in A4
df_tot_p0_deathsA4.boxplot(ax=axs[1])
axs[1].set_title('Total Deaths in A4')
axs[1].set_ylabel('Number of Deaths')

# Boxplot for damage in A5
df_tot_p0_damageA5.boxplot(ax=axs[2])
axs[2].set_title('Annual Damage in A5')
axs[2].set_ylabel('Number of Deaths')

# Boxplot for damage in A4
df_tot_p0_damageA4.boxplot(ax=axs[3])
axs[3].set_title('Annual Damage in A4')
axs[3].set_ylabel('Number of Deaths')

# Boxplot for df_out_costs
df_tot_p0_costs.boxplot(ax=axs[4])
axs[4].set_title('Total Costs')
axs[4].set_ylabel('Costs (in $)')

# Display the boxplots
plt.tight_layout()
plt.show()
