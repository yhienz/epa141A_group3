# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from ema_workbench import load_results
results = load_results('Week22_Open_exploration_PD_5.tar.gz')

# %%
experiments, outcomes = results

# %%
experiments[0:25]

# %%
outcomes

# %%
from ema_workbench.analysis import pairs_plotting

fig, axes = pairs_plotting.pairs_scatter(experiments, outcomes, group_by="policy", legend=False)
fig.set_size_inches(8, 8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 fig, axes = pairs_plotting.pairs_scatter(experiments, outcomes, group_by="policy", legend=False)
#       4 fig.set_size_inches(8, 8)
# ----> 5 plt.show()
#
# NameError: name 'plt' is not defined
