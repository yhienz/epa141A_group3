# %%
import numpy as np
from ema_workbench import load_results
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from ema_workbench import save_results

# %%
results2 = load_results('Week22_Open_exploration_1000_20.tar.gz')

# %%
experiments, outcomes = results2

# %%
outcomes
# Out:
# {'A.1 Total Costs': array([2.40958347e+08, 2.40958347e+08, 2.40958347e+08, ...,
#         3.72552032e+07, 3.72552032e+07, 3.72552032e+07]),
#  'A.1_Expected Number of Deaths': array([0., 0., 0., ..., 0., 0., 0.]),
#  'A.2 Total Costs': array([8.68824465e+07, 9.33436403e+07, 8.48114771e+07, ...,
#         2.17280105e+08, 2.15529778e+08, 2.04666751e+08]),
#  'A.2_Expected Number of Deaths': array([0.00095378, 0.00133667, 0.00031296, ..., 0.01663245, 0.01159013,
#         0.00083144]),
#  'A.3 Total Costs': array([1.33000676e+08, 1.33000676e+08, 1.33000676e+08, ...,
#         9.53174130e+07, 9.53174130e+07, 9.53174130e+07]),
#  'A.3_Expected Number of Deaths': array([0., 0., 0., ..., 0., 0., 0.]),
#  'A.4 Total Costs': array([44334586.47905244, 44334586.47905244, 44334586.47905244, ...,
#         39745013.73511774, 39745013.73511774, 39745013.73511774]),
#  'A.4_Expected Number of Deaths': array([0., 0., 0., ..., 0., 0., 0.]),
# ...

# %%
from ema_workbench.analysis import prim

data = outcomes['A.5 Total Costs']

# With continious outcomes, probably the only way to prim is throufh percentile??

y = data < np.percentile(data, 10)

# Initialize PRIM algorithm with the appropriate mode
prim_alg = prim.Prim(experiments, y, threshold=0.7)
box1 = prim_alg.find_box()

box1.show_tradeoff()
plt.show()
# Out:
# C:\Users\Gebruiker\anaconda3\Lib\site-packages\ema_workbench\analysis\prim.py:1569: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   box_paste.loc[i, u] = paste_value
# C:\Users\Gebruiker\anaconda3\Lib\site-packages\ema_workbench\analysis\prim.py:1569: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   box_paste.loc[i, u] = paste_value
# C:\Users\Gebruiker\anaconda3\Lib\site-packages\ema_workbench\analysis\prim.py:1569: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
box1.inspect(style='graph')
plt.show()

# %%
box1.select(4)
box1.show_pairs_scatter()
fig = plt.gcf()
fig.set_size_inches(12,12)
plt.show()
# Out:
# C:\Users\Gebruiker\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Gebruiker\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Gebruiker\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
